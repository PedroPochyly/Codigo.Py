# %% [markdown]
# # Mundo 13
#
# ### Leitura e extração de dados

# %% [markdown]
# https://data.worldbank.org/
#
# Esses dados podem servir pra montar um ótimo portfólio diferente.

# %%
from pandas_datareader import wb 
from datetime import datetime

# %%
indicadores = wb.get_indicators()

indicadores
# Out:
#                          id  \
# 0        1.0.HCount.1.90usd
# 1         1.0.HCount.2.5usd
# 2      1.0.HCount.Mid10to50
# 3           1.0.HCount.Ofcl
# 4       1.0.HCount.Poor4uds
# ...                     ...
# 24597               w_F_skl
# 24598               w_M_nsk
# 24599               w_M_skl
# 24600             wpremia_F
# 24601             wpremia_M
#
#                                                     name unit  \
# 0                        Poverty Headcount ($1.90 a day)
# 1                        Poverty Headcount ($2.50 a day)
# 2                  Middle Class ($10-50 a day) Headcount
# 3                Official Moderate Poverty Rate-National
# 4                           Poverty Headcount ($4 a day)
# ...                                                  ...  ...
# 24597     Annual wage for skilled female workers  in US$
# 24598     Annual wage for unskilled male workers  in US$
# 24599       Annual wage for skilled male workers  in US$
# ...

# %%
indicadores.head(50)
# Out:
#                                id  \
# 0              1.0.HCount.1.90usd
# 1               1.0.HCount.2.5usd
# 2            1.0.HCount.Mid10to50
# 3                 1.0.HCount.Ofcl
# 4             1.0.HCount.Poor4uds
# 5             1.0.HCount.Vul4to10
# 6                1.0.PGap.1.90usd
# 7                 1.0.PGap.2.5usd
# 8               1.0.PGap.Poor4uds
# 9                1.0.PSev.1.90usd
# 10                1.0.PSev.2.5usd
# 11              1.0.PSev.Poor4uds
# 12             1.1.HCount.1.90usd
# 13              1.1.HCount.2.5usd
# 14           1.1.HCount.Mid10to50
# 15                1.1.HCount.Ofcl
# 16            1.1.HCount.Poor4uds
# 17            1.1.HCount.Vul4to10
# 18               1.1.PGap.1.90usd
# 19                1.1.PGap.2.5usd
# 20              1.1.PGap.Poor4uds
# 21               1.1.PSev.1.90usd
# 22                1.1.PSev.2.5usd
# 23              1.1.PSev.Poor4uds
# 24     1.1_ACCESS.ELECTRICITY.TOT
# 25  1.1_TOTAL.FINAL.ENERGY.CONSUM
# ...

# %%
matches = wb.search('gdp.*capita.*const')

matches
# Out:
#                          id  \
# 691      6.0.GDPpc_constant
# 11165        NY.GDP.PCAP.KD
# 11167        NY.GDP.PCAP.KN
# 11169     NY.GDP.PCAP.PP.KD
# 11170  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 691    GDP per capita, PPP (constant 2011 internation...
# 11165                 GDP per capita (constant 2015 US$)
# 11167                      GDP per capita (constant LCU)
# 11169  GDP per capita, PPP (constant 2021 internation...
# 11170  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 691                  LAC Equity Lab
# 11165  World Development Indicators
# 11167  World Development Indicators
# 11169  World Development Indicators
# 11170         WDI Database Archives
#
#                                               sourceNote  \
# 691    GDP per capita based on purchasing power parit...
# 11165  GDP per capita is gross domestic product divid...
# ...

# %%
pobreza = wb.download(indicator='1.0.HCount.1.90usd', 
                      country=['MEX', 'BRA'], 
                      start=2000, end=2022)

pobreza
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_16208\1959745737.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   pobreza = wb.download(indicator='1.0.HCount.1.90usd',
#               1.0.HCount.1.90usd
# country year
# Brazil  2014            3.663256
#         2013                 NaN
#         2012            4.591671
#         2011            5.500478
#         2010                 NaN
#         2009            6.175147
#         2008            6.286798
#         2007            7.602658
#         2006            7.944849
#         2005            9.553495
#         2004           11.036233
#         2003           12.709325
#         2002           12.310864
#         2001           13.622047
#         2000                 NaN
# Mexico  2014            5.653357
#         2013                 NaN
#         2012            5.944242
# ...

# %% [markdown]
# https://www.worldbank.org/en/topic/poverty/lac-equity-lab1/overview

# %% [markdown]
# # Link com o código dos países:
#
# https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes

# %%
pib = wb.download(indicator='NY.GDP.PCAP.KD', 
                      country=['1W'], 
                      start=1980, end=2022)
print(pib_percapta)

# %%
aumento_em_40_anos = pib_percapta.groupby('country').first()/pib_percapta.groupby('country').last() - 1
                                                                

aumento_em_40_anos

# %%
pib_percapta.loc['Brazil']

# %% [markdown]
# # Exercícios
#
# * Exercício 62: Busque os dados no banco mundial da evolução da emissão de carbono no mundo que tem como nome "CO2 emissions (kt)" desde 1990. Obs: para puxar dados agregados do mundo, a sigla a ser colocada em Country é "1W"

# %%
#gabarito 62

matches = wb.search('co2')

matches.tail(50)

# %%
co2 = wb.download(indicator='EN.ATM.CO2E.KT', 
                      country=['1W'], 
                      start=1990, end=2022)

print(co2)

co2 = co2.dropna()
co2 = co2.droplevel(level = 0)
co2 = co2.sort_index()
co2

# %%
co2.plot()

# %% [markdown]
# # Mundo 14
#
#
# Agora que você já aprendeu a puxar dados do mercado financeiro, economia americana, economia mundial, chegou  o momento de aprender a puxar dados de fac
