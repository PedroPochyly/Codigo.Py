# %% [markdown]
# # Mundo 13 - Anotações em gráficos

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.dates as mdate
import yfinance as yf
from datetime import datetime

# %%
cotacoes = yf.download(["^BVSP"], "2016-01-01", "2018-01-01")['Close']
cotacoes
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker        ^BVSP
# Date
# 2016-01-04  42141.0
# 2016-01-05  42419.0
# 2016-01-06  41773.0
# 2016-01-07  40695.0
# 2016-01-08  40612.0
# ...             ...
# 2017-12-22  75187.0
# 2017-12-26  75688.0
# 2017-12-27  76073.0
# 2017-12-28  76402.0
# 2017-12-29  76402.0
#
# [496 rows x 1 columns]

# %%
data_crises = [(datetime(2017, 5, 17), "Joesley Day"),
              (datetime(2016, 8, 31), "Impeachment Dilma")]
         


fig, ax = plt.subplots()

ax.plot(cotacoes)

for data, evento in data_crises:
    
    ax.annotate(evento, xy = (data, cotacoes.asof(data) + 2800), #posição comeco da seta
                xytext = (data, cotacoes.asof(data) + 10000), #posição texto da seta
                arrowprops = dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
               horizontalalignment = "right", verticalalignment = "top")

    
ax.xaxis.set_major_locator(mdate.YearLocator(1))
# Out:
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:1477: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y = float(self.convert_yunits(y))
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:906: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y = float(self.convert_yunits(self._y))
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:763: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   posy = float(self.convert_yunits(y))

# %%
cotacoes.asof(datetime(2016, 8, 31))

# %%
cotacoes.loc[datetime(2016, 8, 31)]

# %% [markdown]
# # Exercícios
#
# * Exercício 107: Crie um gráfico do ibovespa entre 2020 e 2022 com anotações no início da pandemia e inicío da guerra entre rússia e ucrânia.

# %%
#107

cotacoes = yf.download(["^BVSP"], "2020-01-01", "2023-01-01")['Close']

data_crises = [(datetime(2020, 2, 20), "Início pandemia"),
              (datetime(2022, 2, 24), "Início da guerra Rússia x Ucrânia")]
         


fig, ax = plt.subplots()

ax.plot(cotacoes)

for data, evento in data_crises:
    
    ax.annotate(evento, xy = (data, cotacoes.asof(data) + 5000), 
                xytext = (data, cotacoes.asof(data) + 15000), 
                arrowprops = dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
               horizontalalignment = "left", verticalalignment = "top")

    
ax.xaxis.set_major_locator(mdate.YearLocator(1))
# Out:
# [*********************100%***********************]  1 of 1 completed
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:1477: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y = float(self.convert_yunits(y))
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:906: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y = float(self.convert_yunits(self._y))
# c:\Users\João Felipe\GitHub\Codigo.Py\.venv\Lib\site-packages\matplotlib\text.py:763: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   posy = float(self.convert_yunits(y))

# %% [markdown]
# # Mundo 14
#
# Animações no Matplotlib
