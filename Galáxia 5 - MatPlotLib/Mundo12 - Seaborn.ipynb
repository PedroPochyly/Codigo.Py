# %% [markdown]
# # Mundo 12 - Seaborn
#
# # O seaborn é outro pacotes de gráficos do Python.
#
# Ele segue e compartilha a estrutura do Matplotlib, mas o único objetivo do seaborn é ser um pouco mais intuitivo e mais bonito "naturalmente"

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as mtick
import yfinance as yf

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
cotacoes = yf.download(["PETR4.SA", "^BVSP"])['Close']

retornos_mensais = cotacoes.resample("M").last().pct_change().dropna()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  2 of 2 completed
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_4808\3248086868.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   retornos_mensais = cotacoes.resample("M").last().pct_change().dropna()

# %%
fig, ax = plt.subplots()

sns.boxplot(data = retornos_mensais, orient = "v")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))

plt.show()

# %%
#histograma

fig, ax = plt.subplots()

sns.histplot(retornos_mensais['PETR4.SA'])
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))

plt.show()

# %%
#regressão linear retornos PETR4 x IBOV

cotacoes = yf.download(["PETR4.SA", "^BVSP"])['Close']

retornos = cotacoes.pct_change().dropna()

fig, ax = plt.subplots()

sns.regplot(x = retornos['^BVSP'], y = retornos['PETR4.SA'], line_kws={"color" : "red" })
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))

plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_4808\2558700560.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   retornos = cotacoes.pct_change().dropna()

# %%
#grafico de linha

cotacoes = yf.download(["PETR4.SA", "WEGE3.SA"])['Close']

fig, ax = plt.subplots()

sns.lineplot(data = cotacoes)

plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# # Exercícios
#
# * Exercício 105: Crie um boxsplot utilizando o seaborn com os retornos mensais das empresas LREN3 e EQTL3.
# * Exercício 106: Crie uma regressão linear com o seaborn entre os retornos de PETR3 e PETR4.

# %%
#105

cotacoes = yf.download(["LREN3.SA", "EQTL3.SA"])['Close']

retornos_mensais = cotacoes.resample("M").last().pct_change().dropna()

fig, ax = plt.subplots()

sns.boxplot(data = retornos_mensais, orient = "v")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))

plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_4808\3174157020.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   retornos_mensais = cotacoes.resample("M").last().pct_change().dropna()

# %%
#106


cotacoes = yf.download(["PETR4.SA", "PETR3.SA"])['Close']

retornos = cotacoes.pct_change().dropna()

fig, ax = plt.subplots()

sns.regplot(x = retornos['PETR3.SA'], y = retornos['PETR4.SA'], line_kws={"color" : "red" })
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0))

plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
