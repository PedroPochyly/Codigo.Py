# %% [markdown]
# # Mundo 4 - Selenium + dados do DI

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from webdriver-manager) (2.32.3)
# Collecting python-dotenv (from webdriver-manager)
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: packaging in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from requests->webdriver-manager) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from requests->webdriver-manager) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from requests->webdriver-manager) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joão felipe\github\codigo.py\.venv\lib\site-packages (from requests->webdriver-manager) (2025.1.31)
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.1.0 webdriver-manager-4.0.2

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from datetime import datetime

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 
#isso aqui evita o inferno de baixar o driver certo

# %%
data_di = "03/02/2023"
mercadoria = 'DI1'

# %%
url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={data_di}&Mercadoria={mercadoria}
'''

# %%
from selenium.webdriver.chrome.options import Options

# %%
options = Options()
options.headless = True

# %%
driver.get(url)

driver.implicitly_wait(3)

'''
esse método de congelar é MUITO mais eficiente que o time, porque ele só espera o tempo necessário.
se o elemento que você quer achar já carregou, ele roda e acabou. 
'''

driver.maximize_window() #maximar a tela do navegador do bot

# %%
#driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = options) 


local_tabela = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

local_indice = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

elemento = driver.find_element("xpath", local_tabela)

#pode ser ID, class_, XPATH ou name (vc so vai usar um dos 4)

elemento_indice = driver.find_element("xpath", local_indice)

html_tabela = elemento.get_attribute('outerHTML')
html_indice = elemento_indice.get_attribute('outerHTML')

tabela = pd.read_html(html_tabela)[0]
indice = pd.read_html(html_indice)[0]


#se colocar tudo junto pode dar merda no JS
# Out:
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_19904\1062603578.py:21: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabela = pd.read_html(html_tabela)[0]
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_19904\1062603578.py:22: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indice = pd.read_html(html_indice)[0]

# %%
driver.quit()

# %%
tabela
# Out:
#                    0                   1             2           3   \
# 0   AJUSTE ANTER. (3)  AJUSTE CORRIG. (4)  PREÇO ABERT.  PREÇO MÍN.
# 1           99.190,76           99.190,76         13652       13650
# 2           98.037,60           98.037,60         13660       13658
# 3           97.142,56           97.142,56         13700       13674
# 4           96.055,26           96.055,26         13705       13705
# 5           95.027,78           95.027,78         13725       13715
# 6           94.006,29           94.006,29         13740       13740
# 7           92.912,59           92.912,59         13780       13775
# 8           91.975,18           91.975,18         13765       13730
# 9           91.001,77           91.001,77         13765       13740
# 10          90.091,18           90.091,18         13750       13750
# 11          89.209,65           89.209,65         13710       13660
# 12          88.249,78           88.249,78         13670       13665
# 13          86.582,36           86.582,36         13675       13570
# 14          84.065,75           84.065,75         13500       13415
# 15          81.601,58           81.601,58         13325       13240
# 16          79.309,22           79.309,22         13160       13080
# 17          77.111,75           77.111,75         13105       13015
# 18          74.959,67           74.959,67         13015       12970
# 19          72.656,44           72.656,44         13055       12985
# 20          70.454,81           70.454,81         13015       12940
# 21          68.432,08           68.432,08         13035       12975
# 22          66.438,01           66.438,01         13055       12955
# 23          64.389,50           64.389,50         13055       12995
# 24          62.481,72           62.481,72         13005       12960
# 25          60.693,94           60.693,94         13060       13060
# 31            13410           13440
# 32             0000           13390
# 33            13400           13420
# 34             0000            0000
# 35             0000            0000
# 36             0000            0000
# 37             0000            0000
# 38             0000            0000

# %%
tabela.columns = tabela.loc[0]

tabela = tabela['ÚLT. PREÇO']

tabela = tabela.drop(0, axis = 0)

indice.columns = indice.loc[0]

indice_di = indice['VENCTO']

indice = indice.drop(0, axis = 0)

tabela.index = indice['VENCTO']

tabela = tabela.astype(int)

tabela = tabela[tabela != 0]

tabela = tabela/1000

print(tabela)
# Out:
# VENCTO
# H23    13.652
# J23    13.670
# K23    13.692
# M23    13.765
# N23    13.790
# Q23    13.835
# U23    13.865
# V23    13.855
# X23    13.875
# Z23    13.805
# F24    13.830
# G24    13.810
# J24    13.740
# N24    13.590
# V24    13.410
# F25    13.275
# J25    13.210
# N25    13.175
# V25    13.155
# F26    13.165
# J26    13.115
# N26    13.180
# V26    13.160
# F27    13.180
# J27    13.145
# N27    13.200
# V27    13.180
# F28    13.225
# F29    13.330
# F30    13.350
# F31    13.410
# F32    13.370
# F33    13.400
# F37    13.350
# Name: ÚLT. PREÇO, dtype: float64

# %%
driver.quit()

# %% [markdown]
# # Exercícios
#
# * Exercício 142: Pegue a tabela com os dados do DI e transforme os códigos do índice em datas do pandas (datetime)
# * Exercício 143: Estraia dados do mini contrato de índice do site da B3 em um data a sua escolha.

# %%
legenda = pd.Series(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    index = ['F', 'G', 'H', 'J', 'K', 'M', 'N', 'Q', 'U', 'V', 'X', 'Z'])

lista_datas = []

for indice in tabela.index:

    letra = indice[0]
    
    legenda["F"]
    ano = indice[1:3]

    mes = legenda[letra]

    data = f"{mes}-{ano}"

    data = datetime.strptime(data, "%b-%y")

    lista_datas.append(data)


tabela.index = lista_datas  

tabela
# Out:
# 2023-03-01    13.652
# 2023-04-01    13.670
# 2023-05-01    13.692
# 2023-06-01    13.765
# 2023-07-01    13.790
# 2023-08-01    13.835
# 2023-09-01    13.865
# 2023-10-01    13.855
# 2023-11-01    13.875
# 2023-12-01    13.805
# 2024-01-01    13.830
# 2024-02-01    13.810
# 2024-04-01    13.740
# 2024-07-01    13.590
# 2024-10-01    13.410
# 2025-01-01    13.275
# 2025-04-01    13.210
# 2025-07-01    13.175
# 2025-10-01    13.155
# 2026-01-01    13.165
# 2026-04-01    13.115
# 2026-07-01    13.180
# 2026-10-01    13.160
# 2027-01-01    13.180
# 2027-04-01    13.145
# 2027-07-01    13.200
# 2027-10-01    13.180
# 2028-01-01    13.225
# 2029-01-01    13.330
# 2030-01-01    13.350
# 2031-01-01    13.410
# 2032-01-01    13.370
# 2033-01-01    13.400
# 2037-01-01    13.350
# Name: ÚLT. PREÇO, dtype: float64

# %%
data = "03/02/2023"
mercadoria = 'WIN'

url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={data}&Mercadoria={mercadoria}
'''

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 

driver.get(url)

driver.implicitly_wait(3)


driver.maximize_window() 

local_tabela = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

local_indice = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

elemento = driver.find_element("xpath", local_tabela)

elemento_indice = driver.find_element("xpath", local_indice)

html_tabela = elemento.get_attribute('outerHTML')
html_indice = elemento_indice.get_attribute('outerHTML')

tabela = pd.read_html(html_tabela)[0]
indice = pd.read_html(html_indice)[0]

driver.quit()
# Out:
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_19904\3718692050.py:33: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabela = pd.read_html(html_tabela)[0]
# C:\Users\João Felipe\AppData\Local\Temp\ipykernel_19904\3718692050.py:34: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   indice = pd.read_html(html_indice)[0]

# %%
legenda = pd.Series(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    index = ['F', 'G', 'H', 'J', 'K', 'M', 'N', 'Q', 'U', 'V', 'X', 'Z'])

lista_datas = []

for indice in tabela.index:

    letra = indice[0]
    
    legenda["F"]
    ano = indice[1:3]

    mes = legenda[letra]

    data = f"{mes}-{ano}"

    data = datetime.strptime(data, "%b-%y")

    lista_datas.append(data)


tabela.index = lista_datas  

tabela

tabela.columns = tabela.loc[0]

tabela = tabela['AJUSTE']

tabela = tabela.drop(0, axis = 0)

indice.columns = indice.loc[0]

indice_di = indice['VENCTO']

indice = indice.drop(0, axis = 0)

tabela.index = indice['VENCTO']

tabela = tabela[tabela != "0"]

print(tabela)

legenda = pd.Series(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    index = ['F', 'G', 'H', 'J', 'K', 'M', 'N', 'Q', 'U', 'V', 'X', 'Z'])

lista_datas = []

for indice in tabela.index:

    letra = indice[0]
    ano = indice[1:3]

    mes = legenda[letra]

    data = f"{mes}-{ano}"

    data = datetime.strptime(data, "%b-%y")

    lista_datas.append(data)


tabela.index = lista_datas  

tabela

# %%
#gabarito 143

data = "03/02/2023"
mercadoria = 'WIN'

url = f'''
https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/SistemaPregao1.asp?pagetype=pop&caminho=Resumo%20
Estat%EDstico%20-%20Sistema%20Preg%E3o&Data={data}&Mercadoria={mercadoria}
'''

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install())) 

driver.get(url)

driver.implicitly_wait(3)


driver.maximize_window() 

local_tabela = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[3]/table
'''

local_indice = '''
/html/body/div/div[2]/form[1]/table[3]/tbody/tr[3]/td[1]/table
'''

elemento = driver.find_element("xpath", local_tabela)

elemento_indice = driver.find_element("xpath", local_indice)

html_tabela = elemento.get_attribute('outerHTML')
html_indice = elemento_indice.get_attribute('outerHTML')

tabela = pd.read_html(html_tabela)[0]
indice = pd.read_html(html_indice)[0]

driver.quit()

# %%
tabela

# %%
tabela.columns = tabela.loc[0]

tabela = tabela['AJUSTE']

tabela = tabela.drop(0, axis = 0)

indice.columns = indice.loc[0]

indice_di = indice['VENCTO']

indice = indice.drop(0, axis = 0)

tabela.index = indice['VENCTO']

tabela = tabela[tabela != "0"]

print(tabela)

# %%
legenda = pd.Series(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                    index = ['F', 'G', 'H', 'J', 'K', 'M', 'N', 'Q', 'U', 'V', 'X', 'Z'])

lista_datas = []

for indice in tabela.index:

    letra = indice[0]
    ano = indice[1:3]

    mes = legenda[letra]

    data = f"{mes}-{ano}"

    data = datetime.strptime(data, "%b-%y")

    lista_datas.append(data)


tabela.index = lista_datas  

tabela
