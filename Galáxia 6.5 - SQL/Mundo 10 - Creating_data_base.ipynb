# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# !pip install mysql-connector-python

# %%
# !pip install sqlalchemy

# %%
# !pip install pymysql

# %%
user = "root"
senha = "1234"
banco_de_dados = "mercado_br"
host = "localhost"
porta = 3306

conexao = create_engine(url=f"mysql+pymysql://{user}:{senha}@{host}:{porta}/{banco_de_dados}")

# %%
dados_fechamento = pd.read_csv('factStocks.csv')
cadastro_moedas = pd.read_csv('dimCoin.csv')
cadastro_empresas= pd.read_csv('dimcompany.csv')
descricao_tempo = pd.read_csv('dimTime.csv')
dados_cambio = pd.read_csv('factCoins.csv')

# %%
dados_cambio.tail(50)
# Out:
#        keyTime  keyCoin  valueCoin
# 13250     6629        1       5.35
# 13251     6629        2       6.67
# 13252     6630        1       5.32
# 13253     6630        2       6.99
# 13254     6631        1       5.35
# 13255     6631        2       6.73
# 13256     6632        1       5.33
# 13257     6632        2       6.78
# 13258     6633        1       5.28
# 13259     6633        2       6.92
# 13260     6634        1       5.23
# 13261     6634        2       6.67
# 13262     6635        1       5.16
# 13263     6635        2       6.85
# 13264     6636        1       5.17
# 13265     6636        2       6.57
# 13266     6637        1       5.10
# 13267     6637        2       6.42
# 13268     6638        1       5.09
# 13269     6638        2       6.49
# 13270     6639        1       5.11
# 13271     6639        2       6.64
# 13272     6640        1       5.09
# 13273     6640        2       6.58
# 13274     6641        1       5.07
# 13275     6641        2       6.67
# 13276     6642        1       5.06
# 13277     6642        2       6.46
# 13278     6643        1       5.10
# 13279     6643        2       6.54
# 13280     6644        1       5.11
# 13281     6644        2       6.76
# 13282     6645        1       5.06
# 13283     6645        2       6.75
# 13284     6646        1       5.10
# 13285     6646        2       6.46
# 13286     6647        1       5.16
# 13287     6647        2       6.72
# 13288     6648        1       5.15
# 13289     6648        2       6.81
# 13290     6649        1       5.17
# 13291     6649        2       6.81
# 13292     6650        1       5.18
# 13293     6650        2       6.51
# 13294     6651        1       5.24
# 13295     6651        2       6.63
# 13296     6652        1       5.19
# 13297     6652        2       6.50
# 13298     6653        1       5.20
# 13299     6653        2       6.52

# %%
dados_cambio = dados_cambio.drop(13300, axis = 0)
dados_cambio = dados_cambio.drop(13301, axis = 0)

# %%
cadastro_moedas.to_sql('cadastro_moedas', conexao, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'cadastro_moedas.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cadastro_moedas.to_sql('cadastro_moedas', conexao, index=False, if_exists='append')
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)   3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)   2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)   1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)   1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)   1657         ret,
#    1658     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931                 break
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#    1940     if self.dialect._has_events:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#     174         context._rowcount = rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218         sql += b","
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#     222 return rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'cadastro_moedas.PRIMARY'")
# [SQL: INSERT INTO cadastro_moedas (`keyCoin`, `abbrevCoin`, `nameCoin`, `symbolCoin`) VALUES (%(keyCoin)s, %(abbrevCoin)s, %(nameCoin)s, %(symbolCoin)s)]
# [parameters: [{'keyCoin': 1, 'abbrevCoin': 'USD', 'nameCoin': 'DOLAR', 'symbolCoin': '$'}, {'keyCoin': 2, 'abbrevCoin': 'EUR', 'nameCoin': 'EURO', 'symbolCoin': '€'}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
dados_fechamento.to_sql('dados_fechamento', conexao, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:215, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     214 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 215     rows += self.execute(sql + postfix)
#     216     sql = bytearray(prefix)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1355-18' for key 'dados_fechamento.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dados_fechamento.to_sql('dados_fechamento', conexao, index=False, if_exists='append')
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)   3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)   2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)   1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)   1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)   1657         ret,
#    1658     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931                 break
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#    1940     if self.dialect._has_events:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#     174         context._rowcount = rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:215, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     213     v = v.encode(encoding, "surrogateescape")
#     214 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 215     rows += self.execute(sql + postfix)
#     216     sql = bytearray(prefix)
#     217 else:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\pedro\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1355-18' for key 'dados_fechamento.PRIMARY'")
# [SQL: INSERT INTO dados_fechamento (`keyTime`, `keyCompany`, `openValueStock`, `closeValueStock`, `highValueStock`, `lowValueStock`, `quantityStock`) VALUES (%(keyTime)s, %(keyCompany)s, %(openValueStock)s, %(closeValueStock)s, %(highValueStock)s, %(lowValueStock)s, %(quantityStock)s)]
# [parameters: [{'keyTime': 1355, 'keyCompany': 18, 'openValueStock': 45.8, 'closeValueStock': 45.8, 'highValueStock': 45.8, 'lowValueStock': 45.8, 'quantityStock': 916.0}, {'keyTime': 1355, 'keyCompany': 107, 'openValueStock': 12.15, 'closeValueStock': 12.6, 'highValueStock': 12.6, 'lowValueStock': 12.15, 'quantityStock': 668420.0}, {'keyTime': 1355, 'keyCompany': 108, 'openValueStock': 17.0, 'closeValueStock': 17.5, 'highValueStock': 17.5, 'lowValueStock': 16.95, 'quantityStock': 3789172.0}, {'keyTime': 1355, 'keyCompany': 604, 'openValueStock': 299.0, 'closeValueStock': 299.0, 'highValueStock': 299.0, 'lowValueStock': 299.0, 'quantityStock': 59800.0}, {'keyTime': 1355, 'keyCompany': 110, 'openValueStock': 53.1, 'closeValueStock': 52.0, 'highValueStock': 53.8, 'lowValueStock': 52.0, 'quantityStock': 8331641.0}, {'keyTime': 1355, 'keyCompany': 111, 'openValueStock': 57.0, 'closeValueStock': 56.5, 'highValueStock': 57.0, 'lowValueStock': 55.5, 'quantityStock': 9327191.0}, {'keyTime': 1355, 'keyCompany': 100, 'openValueStock': 10.9, 'closeValueStock': 10.95, 'highValueStock': 10.95, 'lowValueStock': 10.65, 'quantityStock': 8684946.4}, {'keyTime': 1355, 'keyCompany': 11, 'openValueStock': 42.0, 'closeValueStock': 41.89, 'highValueStock': 42.0, 'lowValueStock': 41.8, 'quantityStock': 171670.0}  ... displaying 10 of 680150 total bound parameter sets ...  {'keyTime': 9672, 'keyCompany': 522, 'openValueStock': 84.15, 'closeValueStock': 82.99, 'highValueStock': 84.54, 'lowValueStock': 82.0, 'quantityStock': 53535.32}, {'keyTime': 9680, 'keyCompany': 522, 'openValueStock': 74.3, 'closeValueStock': 73.7, 'highValueStock': 75.07, 'lowValueStock': 71.64, 'quantityStock': 145087.74}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
